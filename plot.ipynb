# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook
import numpy as np

data = np.genfromtxt('/home/merbar/git/CarND-Path-Planning-Project/data/highway_map.csv', delimiter=' ')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.set_title("Track")    
ax1.plot(data[:,0],data[:,1], c='r')

plt.show()
